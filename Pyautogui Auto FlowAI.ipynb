# %%
import pyautogui # Main module to control keyboard and mouse
import time # used to add pauses
import os # used to open folders

# %%
#### Program to Run FlowAI automatically

### Used during the analysis of TCellFullRun

### By David Wullimann

# %%
### This program uses pyautogui

### Useful commands:

pyautogui.mouseInfo() # Tool to get mouse coordinates
print(pyautogui.position()) # Get current mouse coordinates
print(pyautogui.size()) # Get screen size 

#This program was optimized for a Size(width=3840, height=2160)
# Out:
# Point(x=2299, y=228)
# Size(width=3840, height=2160)

# %%
## This is the window I have for the start of the loop, run before executing the loop. 

time.sleep(1)
os.startfile(r"P:\David Wullimann\TCellFullRun\Experiments\C")
time.sleep(1)


## Make sure to open Advanced Options with the Arrow, it is not included in the loop!

# %%
initial_y = 550
y_increment = 51

# %%
## CHANGING TO TAKE ALL SAMPLES NOW THAT RAM HAS BEEN CHANGED

## 96 SAMPLES

sample_list = ["E-12", "E-20", "E-15", "E-21"]

initial_y = 550
y_increment = 51


#875,550 coordinates for the first folder in list


for item in sample_list:
    

    # Move to first folder
    time.sleep(2)
    pyautogui.moveTo(875, initial_y, duration=1) # Move to First folder in list
    pyautogui.click(clicks=2)
    time.sleep(3)
    pyautogui.moveTo(975, 550, duration = 1) # Move to 96 Well - V-bottom folder
    pyautogui.click()
    time.sleep(3)
    pyautogui.mouseDown()
    pyautogui.moveTo(2173, 2103, duration = 1) # drag files into FlowJo
    time.sleep(2)
    pyautogui.moveTo(181,487, duration = 1) # drag folder into FlowJo
    pyautogui.mouseUp()
    time.sleep(2)
    pyautogui.moveTo(943,2101, duration = 1) # Folders
    pyautogui.click(button='right')
    pyautogui.moveTo(818,2005, duration = 1) # Close all windows
    pyautogui.click()

    
    # Close pop ups

    # more times?
    pyautogui.moveTo(2346,1133, duration = 1) # Close pop up window
    pyautogui.click()
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(3)
    pyautogui.press('enter') 
    time.sleep(3)
    pyautogui.press('enter') 
    time.sleep(3)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(10)
    pyautogui.press('enter') 
    time.sleep(5)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    time.sleep(2)
    pyautogui.press('enter') 
    
    
    # Save the file

    time.sleep(3)
    with pyautogui.hold('ctrl'):
            pyautogui.press('s')
    time.sleep(1)
    pyautogui.write(item + "_flowai", interval=0.4)
    pyautogui.moveTo(1320,892, duration = 1) # Desktop
    pyautogui.click()
    pyautogui.moveTo(1555,1264, duration = 1) # GoodEvents folder
    pyautogui.click(clicks=2)
    pyautogui.moveTo(2512,1428, duration = 1) # Save
    pyautogui.click(clicks = 2)
    time.sleep(3)

    #Run FlowAI

    pyautogui.moveTo(334,851, duration = 1) # First sample
    pyautogui.click()
    pyautogui.moveTo(615,150, duration = 1) # Workspace
    pyautogui.click() 
    pyautogui.moveTo(1522,251, duration = 1) # Plugin
    pyautogui.click() 
    pyautogui.moveTo(1613,622, duration = 1) # FlowAI
    pyautogui.click()
    time.sleep(3)

    #FlowAI window

    pyautogui.moveTo(2498,655, duration = 1) # Go to scroll bar
    time.sleep(1)
    pyautogui.mouseDown()
    pyautogui.moveTo(2501,944, duration = 1) # Scroll down
    time.sleep(1)
    pyautogui.mouseUp()
    pyautogui.moveTo(1425,1012, duration = 1) # Go to Time
    pyautogui.keyDown('ctrl')
    pyautogui.click() 
    pyautogui.keyUp('ctrl')
    pyautogui.moveTo(2464,1215, duration = 1) # Go to Changepoint penalty
    pyautogui.click(clicks=2)
    pyautogui.write("500", interval=0.2)
    pyautogui.moveTo(1823,1672, duration = 1) # Okay
    pyautogui.click()
    time.sleep(3)
    
    time.sleep(120)

    pyautogui.moveTo(289,930, duration = 1) # FlowAI red icon
    pyautogui.mouseDown()
    pyautogui.moveTo(251,533, duration = 1) # Apply to whole group
    time.sleep(1)
    pyautogui.mouseUp()
    pyautogui.press('enter')

    #For 72 samples: Run 45 minutes (2700 sec) but move mouse to prevent sleep every 540 sec
    #For 92 samples: 63 minutes (540*7 sec)
    
    time.sleep(540)
    pyautogui.moveTo(896,89, duration = 2)
    pyautogui.click()
    pyautogui.moveTo(1241,84, duration = 2)
    time.sleep(540)
    pyautogui.moveTo(896,89, duration = 2)
    pyautogui.click()
    pyautogui.moveTo(1241,84, duration = 2)
    time.sleep(540)
    pyautogui.moveTo(896,89, duration = 2)
    pyautogui.click()
    pyautogui.moveTo(1241,84, duration = 2)
    time.sleep(540)
    pyautogui.moveTo(896,89, duration = 2)
    pyautogui.click()
    pyautogui.moveTo(1241,84, duration = 2)
    time.sleep(540)
    pyautogui.moveTo(896,89, duration = 2)
    pyautogui.click()
    pyautogui.moveTo(1241,84, duration = 2)
    time.sleep(540)
    pyautogui.moveTo(896,89, duration = 2)
    pyautogui.click()
    pyautogui.moveTo(1241,84, duration = 2)
    #time.sleep(540)
    #pyautogui.moveTo(896,89, duration = 2)
    #pyautogui.click()
    #pyautogui.moveTo(1241,84, duration = 2)
    #time.sleep(540)
    #pyautogui.moveTo(896,89, duration = 2)
    #pyautogui.click()
    #pyautogui.moveTo(1241,84, duration = 2)

    
    #Select GoodEvents and open Export Windows

    pyautogui.moveTo(383,1020, duration = 1) # Go to first sample GoodEvents
    pyautogui.click()
    time.sleep(1)
    with pyautogui.hold(['shift', "ctrl"]):
            pyautogui.press("e")
    with pyautogui.hold("ctrl"):
            pyautogui.press("e")
    time.sleep(3)

    #Navigate Export Window

    #Move window
    pyautogui.moveTo(2201,1069, duration = 1)
    pyautogui.mouseDown()
    pyautogui.moveTo(1530,537, duration = 1) #  
    time.sleep(1)
    pyautogui.mouseUp()

    #Change Destination


    pyautogui.moveTo(1605,825, duration = 1) # Destination 
    pyautogui.click()
    time.sleep(2)
    pyautogui.write(r"C:\Users\davwul\OneDrive - KI.SE\Skrivbordet\GoodEvents")
    time.sleep(2)
    pyautogui.moveTo(2529,1429, duration = 1) # Open
    pyautogui.click()
    time.sleep(1)
    pyautogui.click()
    pyautogui.moveTo(2529,1430, duration = 1) # Open
    time.sleep(1)
    pyautogui.click()
    
    #Advanced Options
    #pyautogui.moveTo(2403,1185, duration = 1) # Arrow
    #pyautogui.click()
    
    #Important: do not need to use above code if you open arrow once manually

    # Set parameters
    pyautogui.moveTo(1933,1086, duration = 1) # custom set
    pyautogui.click()
    pyautogui.moveTo(2347,1089, duration = 1) # View/Edit
    pyautogui.click()
    time.sleep(3)


    #Move window
    pyautogui.moveTo(2045,1243, duration = 1) # click top header
    pyautogui.mouseDown()
    pyautogui.moveTo(1620,570, duration = 1) # Move window here
    time.sleep(1)
    pyautogui.mouseUp()
    pyautogui.moveTo(2177,838, duration = 1) # Move to scroll
    pyautogui.mouseDown()
    pyautogui.moveTo(2177,1344, duration = 1) # scroll down
    time.sleep(1)
    pyautogui.mouseUp()
    pyautogui.moveTo(1537,1372, duration = 1) # FlowAI
    with pyautogui.hold("ctrl"):
            pyautogui.click()
    pyautogui.moveTo(2031,1700, duration = 1) # Okay
    pyautogui.click()
    time.sleep(3)


    #Delete prefix
    pyautogui.moveTo(1479,1301, duration = 1) # Prefix Window
    pyautogui.click(clicks=2)
    time.sleep(1)
    pyautogui.hotkey("delete")
    time.sleep(1)

    #Write Suffix
    pyautogui.moveTo(1461,1571, duration = 1) # Suffix window
    pyautogui.click()
    pyautogui.typewrite(item, interval=0.3)

    #Export
    pyautogui.moveTo(2166,1827, duration = 1) # Export
    pyautogui.click()
    time.sleep(30) # wait for exporting
    pyautogui.moveTo(2415,1557, duration = 1) # Close
    pyautogui.click()
    pyautogui.moveTo(2370,1827, duration = 1) # Cancel
    pyautogui.click()
    time.sleep(3)

    # Close Flowjo and open New FlowJo workspace

    pyautogui.moveTo(3780,22, duration = 1) # Close window
    pyautogui.click()
    time.sleep(1)
    pyautogui.moveTo(1968,1136, duration = 2) # Yes to save
    pyautogui.click()
    time.sleep(1)
    pyautogui.moveTo(1814,671) # New Flowjo
    pyautogui.click()
    pyautogui.moveTo(1349,90, duration = 1) # Enlarge Flowjo Workspace
    pyautogui.click()
    time.sleep(5)
    
    # Go to Desktop to reset
    with pyautogui.hold("win"):
        pyautogui.press("d")
            
     # First window to start (folder with samples)
    os.startfile(r"P:\David Wullimann\TCellFullRun\Experiments\Att köra")
    time.sleep(1)
    with pyautogui.hold('win'):
        pyautogui.press('up')
    time.sleep(3)
    
    initial_y += y_increment
    
    
    time.sleep(20)

# %%
pyautogui.mouseInfo()

# %%
time.sleep(5)
button9location = pyautogui.locateOnScreen('calc_9.PNG')
button9location
# Out:
# Box(left=3058, top=1215, width=237, height=91)

# %%
time.sleep(1)
button9point = pyautogui.center(button9location)
button9point
button9x, button9y = button9point

# %%
pyautogui.click(button9x, button9y)

# %%
    ### FlowJo Create group

    pyautogui.moveTo(458, 213, duration = 1) # create group
    pyautogui.click() 
    pyautogui.moveTo(1418, 213, duration = 1) # Name S
    pyautogui.click() 
    pyautogui.press('S') 
    pyautogui.moveTo(2195,1371, duration = 1) # Create
    pyautogui.click() 
    pyautogui.moveTo(2450,1379, duration = 1) # Exit
    pyautogui.click() 

    # Drag samples into S group

    pyautogui.moveTo(181,487, duration = 1) # All Samples
    pyautogui.click() 
    pyautogui.moveTo(334,851, duration = 1) # First sample
    pyautogui.click() 
    time.sleep(2)
    with pyautogui.hold('ctrl'):
            pyautogui.press('a')
    time.sleep(2)
    pyautogui.mouseDown()
    pyautogui.moveTo(139,585, duration = 1) # Move to S Group
    time.sleep(1)
    pyautogui.mouseUp()
    time.sleep(1)
    pyautogui.click() 
    pyautogui.moveTo(334,851, duration = 1) # First sample
